# %% [markdown]
# <a href="https://colab.research.google.com/github/prayasshrivastava/Machine-learning/blob/master/webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url='https://www.hackerrank.com/challenges/python-mutations/problem'

# %%
# we are sending requests to the url and taking the response

response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-us">\n<head>\n  <meta charSet="utf-8"/>\n  \n  <title> Mutations | HackerRank </title><meta name="description" id="meta-description" content="Understand immutable vs mutable by making changes to a given string."/><meta property="og:title" id="meta-og-title" content="Mutations | HackerRank"/><meta property="og:image" id="meta-og-image" content="https://hrcdn.net/og/default.jpg"/><meta property="og:description" id="meta-og-description" content="Understand immutable vs mutable by making changes to a given string."/><meta property="og:url" id="meta-og-url" content="https://www.hackerrank.com/challenges/python-mutations/problem"/><meta property="og:site_name" id="meta-og-site" content="HackerRank"/><meta property="og:type" id="meta-og-type" content="website"/><meta property="article:author" content="https://www.facebook.com/hackerrank"/><meta name="twitter:card" id="meta-twitter-card" content="summary"/><meta name="twitter:site" id="meta-twitter-site" cont
# ...

# %%
# parsing library - html.parser and second is lxml

soup=BeautifulSoup(response.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-us">
# <head>
# <meta charset="utf-8"/>
# ...

# %%
for Alink in soup.find_all('a'):
  print(Alink)
# Out:
# <a class="cookie-link" href="/privacy#cookies" target="_blank">cookie policy</a>
# <a class="nav_link backbone logo_mark js_logo_mark logo-link" data-analytics="NavBarLogo" data-attr1="/" href="/"><img alt="" class="logo-img-small" id="feed-intro" src="https://hrcdn.net/fcore/assets/brand/h_mark_sm-966d2b45e3.svg"/></a>
# <a class="nav-link dashboard active" data-analytics="NavBarDomains" href="/dashboard"><span>Practice</span></a>
# <a class="nav-link contests" data-analytics="NavBarContests" href="/contests"><span>Compete</span></a>
# <a class="nav-link" data-analytics="NavBarJobs" href="/jobs"><span>Jobs</span><i class="ui-icon-circle-filled notification-indicator hidden"></i></a>
# <a class="nav-link" data-analytics="NavBarLeaderboard" href="/leaderboard" id="leaderboard-nav-link"><span>Leaderboard</span></a>
# ...

# %%
print(Alink.get('href'))
# Out:
# /support/feature

# %%
for ptag in soup.find_all('p'):
  print(ptag)
# Out:
# <p>We have seen that lists are mutable (they can be changed), and tuples are immutable (they cannot be changed).  </p>
# <p>Let's try to understand this with an example.  </p>
# <p>You are given an immutable string, and you want to make changes to it.  </p>
# <p><strong>Example</strong> </p>
# <p>You can access an index by:  </p>
# <p>What if you would like to assign a value?  </p>
# <p>How would you approach this?</p>
# <p><strong>Example</strong> </p>
# <p>Example </p>
# <p><strong>Task</strong> <br/>
# Read a given string, change the character at a given index and then print the modified string.  </p>
# <p><strong>Input Format</strong> <br/>
# ...

# %%
# now second loop for b tag

for btag in ptag.find_all('b'):
  print(btag.text)

# %%
import pandas as pd

# %%
list=[1,2,3,4]
df=pd.DataFrame(list)

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
list1=[3,4,5,6]
df=pd.DataFrame([list,list1],columns=['age','value','name','marks'])
df
# Out:
#    age  value  name  marks
# 0    1      2     3      4
# 1    3      4     5      6

# %%
list1=["Prayas",19,78]
list2=["Paveen",20,78]
list3=["Jayesh",21,89]
df=pd.DataFrame([list1,list2,list3],columns=['name','age','marks'])
df
# Out:
#      name  age  marks
# 0  Prayas   19     78
# 1  Paveen   20     78
# 2  Jayesh   21     89
